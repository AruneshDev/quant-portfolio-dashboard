# %%
pip install --upgrade yfinance
# Out:
# ...
#   Using cached yfinance-0.2.54-py2.py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached pandas-2.2.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (89 kB)
# ...
#   Using cached numpy-2.2.3-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached frozendict-2.4.6-py313-none-any.whl.metadata (23 kB)
# ...
#   Using cached peewee-3.17.9-cp313-cp313-macosx_15_0_arm64.whl
# ...
#   Using cached beautifulsoup4-4.13.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached charset_normalizer-3.4.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (35 kB)
# ...

# %%
import yfinance as yf

ticker = "AAPL"
data = yf.download(ticker, period="1d", auto_adjust=False)
print(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low    Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL    AAPL      AAPL
# Date
# 2025-03-14  213.490005  213.490005  213.949997  209.580002  211.25  60060200

# %%
import yfinance as yf

# Function to fetch historical stock data
def get_historical_data(ticker, period):
    try:
        stock = yf.Ticker(ticker)
        stock_data = stock.history(period=period)
        
        if stock_data.empty:
            print(f"No historical data found for {ticker} with period {period}")
            return
        
        # Print the latest 5 records for verification
        print(f"📈 Historical Data for {ticker} - Period: {period}")
        print(stock_data.tail())  # Show last 5 rows
    except Exception as e:
        print(f"❌ Error fetching data for {ticker}: {str(e)}")

# Test different time periods
test_ticker = "AAPL"  # Change this to any ticker (e.g., "GOOGL", "NVDA", etc.)

time_periods = ["1d", "5d", "1mo", "6mo", "1y", "max"]

for period in time_periods:
    get_historical_data(test_ticker, period)
    print("-" * 50)  # Separator for better readability
# Out:
# 📈 Historical Data for AAPL - Period: 1d
#                              Open        High         Low       Close  \
# Date
# 2025-03-14 00:00:00-04:00  211.25  213.949997  209.580002  213.490005
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-03-14 00:00:00-04:00  60060200        0.0           0.0
# --------------------------------------------------
# 📈 Historical Data for AAPL - Period: 5d
#                                  Open        High         Low       Close  \
# Date
# 2025-03-10 00:00:00-04:00  235.539993  236.160004  224.220001  227.479996
# 2025-03-11 00:00:00-04:00  223.809998  225.839996  217.449997  220.839996
# 2025-03-12 00:00:00-04:00  220.139999  221.750000  214.910004  216.979996
# 2025-03-13 00:00:00-04:00  215.949997  216.839996  208.419998  209.679993
# 2025-03-14 00:00:00-04:00  211.250000  213.949997  209.580002  213.490005
#
#                              Volume  Dividends  Stock Splits
# Date
# ...
